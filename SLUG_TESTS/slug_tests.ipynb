# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import warnings
from scipy.stats import linregress
warnings.simplefilter("ignore")
plt.rcParams["figure.autolayout"] = True
plt.rcParams['axes.grid'] = True
# Out:
# /Applications/anaconda3/envs/mude/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
def import_data(data, Patmo):
    data["datetime"] = pd.to_datetime(data["Datum & tijd"], dayfirst = True)
    data["time_since_start"] = ((data["datetime"] - data["datetime"].min()).dt.total_seconds())
    # starting at the maximum height level 
    index_max = data["Druk (cmH2O)"].idxmax()
    data = data.loc[index_max:]
    # adjusting for atmospheric pressure
    data["height"] = data["Druk (cmH2O)"] - Patmo
    # final arrays
    h = np.array(data["height"])/100
    t = np.array(data["time_since_start"])
    plt.plot(t, h) 
    plt.title("Observed head levels")
    plt.xlabel("time (s)")
    plt.ylabel("head (m)")
    return h,t

# %%
def inv_aug(r, h, t, code):
    k = []

    for i in range(len(h)-1):
        k_sat = 1.15 * r *( (np.log10(h[i] + 0.5*r) - np.log10(h[i+1] + 0.5*r))/(t[i+1] - t[i]))

        k.append(k_sat)
    ht = h + 0.5*r
    
    slope, intercept, r_value, p_value, std_err = linregress(t, np.log(ht))
    
    def model(x):
        return np.exp(intercept + slope * x)

    angle_rad_ccw = np.arctan(slope)
    angle_deg_ccw = np.degrees(angle_rad_ccw)
    
    print("angle", angle_deg_ccw)
    plt.semilogy(t, ht)
    plt.semilogy(t, model(t), '-', label='Fitted line')
    plt.xlabel("Time (s)")
    plt.ylabel("Ht (m)")
    K = 1.15 * r * -slope
    mean_ksat.append(K)
    code_list.append(code)
    return mean_ksat, code_list

# %%
mean_ksat = []
code_list  = []

# %% [markdown]
# Site4_Loc1_BF375_1

# %%
df = pd.read_csv('Site4_Loc1_BF375_1.csv', delimiter=r'\s+', encoding='utf-8', engine='python')
df = df.drop(df.columns[0], axis=1)
column_names = ['Datum & tijd', 'Druk (cmH2O)', "Temperatuur"]
df.columns = column_names
df
# Out:
#   Datum & tijd  Druk (cmH2O)  Temperatuur
# 0   10:12:00.0       961.692       23.300
# 1   10:15:00.0       952.475       22.863
# 2   10:18:00.0       950.142       22.720
# 3   10:21:00.0       949.442       22.363

# %%
plt.figure(figsize = (10, 6))
plt.subplot(121)
Patmo = 950
h, t = import_data(df, Patmo)
code = "Site4_Loc1_BF375_1"

plt.subplot(122)

r = 10/2/100 #radius of bore hole (m)
inv_aug(r, h, t, code)
# Out:
# angle -0.210076241094632
# ([0.00021082596475959354], ['Site4_Loc1_BF375_1'])

# %% [markdown]
# Site4_Loc1_BF375_2

# %%
df = pd.read_csv('Site4_Loc1_BF375_2.csv', delimiter=r'\s+', encoding='utf-8', engine='python')
df = df.drop(df.columns[0], axis=1)
column_names = ['Datum & tijd', 'Druk (cmH2O)', "Temperatuur"]
df.columns = column_names
df
# Out:
#    Datum & tijd  Druk (cmH2O)  Temperatuur
# 0    10:27:00.0       974.525       22.567
# 1    10:30:00.0       969.567       22.620
# 2    10:33:00.0       966.300       22.643
# 3    10:36:00.0       963.383       22.673
# 4    10:39:00.0       957.083       22.673
# 5    10:42:00.0       955.742       22.697
# 6    10:45:00.0       954.167       22.737
# 7    10:48:00.0       953.292       22.753
# 8    10:51:00.0       952.242       22.753
# 9    10:54:00.0       951.308       22.753
# 10   10:57:00.0       949.208       22.760

# %%
plt.figure(figsize = (10, 6))
plt.subplot(121)
Patmo = 950
h, t = import_data(df, Patmo)
code = "Site4_Loc1_BF375_2"

plt.subplot(122)

r = 10/2/100 #radius of bore hole (m)
inv_aug(r, h, t, code)
# Out:
# angle -0.07913662207694286
# ([0.00021082596475959354, 7.94187408159181e-05],
#  ['Site4_Loc1_BF375_1', 'Site4_Loc1_BF375_2'])

# %% [markdown]
# Site4_Loc1_DF002

# %%
df = pd.read_csv('Site4_Loc1_DF002.txt', delimiter = "      ",  encoding='ISO-8859-1', skiprows = 53, skipfooter = 1)
column_names = ['Datum & tijd', 'Druk (cmH2O)', "Temperatuur"]
df.columns = column_names
df
# Out:
#                Datum & tijd  Druk (cmH2O)  Temperatuur
# 0     2024/09/11 09:00:15.0       951.775       21.960
# 1     2024/09/11 09:00:30.0       951.892       21.967
# 2     2024/09/11 09:00:45.0       951.892       21.960
# 3     2024/09/11 09:01:00.0       951.775       21.943
# 4     2024/09/11 09:01:15.0       952.067       21.960
# ...                     ...           ...          ...
# 2352  2024/09/11 18:48:15.0       955.158       26.130
# 2353  2024/09/11 18:48:30.0       955.625       26.297
# 2354  2024/09/11 18:48:45.0       955.858       26.500
# 2355  2024/09/11 18:49:00.0       955.858       26.717
# 2356  2024/09/11 18:49:15.0       956.033       26.857
#
# [2357 rows x 3 columns]

# %%
plt.figure(figsize = (10, 6))
plt.subplot(121)
Patmo = 955

h, t = import_data(df[1000:1800], Patmo)
code = "Site4_Loc1_DF002_1"

plt.subplot(122)

r = 10/2/100 #radius of bore hole (m)
inv_aug(r, h, t, code)
# Out:
# angle -0.004141725241364901
# ([0.00021082596475959354, 7.94187408159181e-05, 4.156487682289258e-06],
#  ['Site4_Loc1_BF375_1', 'Site4_Loc1_BF375_2', 'Site4_Loc1_DF002_1'])

# %% [markdown]
# Site1_Loc4_AL116_1

# %%
df = pd.read_csv('Site1_Loc4_AL116_1.csv', delimiter = "      ",  encoding='ISO-8859-1')
column_names = ['Datum & tijd', 'Druk (cmH2O)', "Temperatuur"]
df.columns = column_names

# %%
plt.figure(figsize = (10, 6))
plt.subplot(121)
Patmo = 955

h, t = import_data(df, Patmo)
code = "Site1_Loc4_AL116_1"

plt.subplot(122)

r = 10/2/100 #radius of bore hole (m)
inv_aug(r, h, t, code)
# Out:
# angle -0.5234499176102145
# ([0.00021082596475959354,
#   7.94187408159181e-05,
#   4.156487682289258e-06,
#   0.0005253302762321573],
#  ['Site4_Loc1_BF375_1',
#   'Site4_Loc1_BF375_2',
#   'Site4_Loc1_DF002_1',
#   'Site1_Loc4_AL116_1'])

# %% [markdown]
# Site1_Loc4_AL116_2

# %%
df = pd.read_csv('Site1_Loc4_AL116_2.csv', delimiter = "      ",  encoding='ISO-8859-1')
column_names = ['Datum & tijd', 'Druk (cmH2O)', "Temperatuur"]
df.columns = column_names

# %%
plt.figure(figsize = (10, 6))
plt.subplot(121)
Patmo = 955

h, t = import_data(df, Patmo)
code = "Site1_Loc4_AL116_2"

plt.subplot(122)

r = 10/2/100 #radius of bore hole (m)
inv_aug(r, h, t, code)
# Out:
# angle -0.16211232405304435
# ([0.00021082596475959354,
#   7.94187408159181e-05,
#   4.156487682289258e-06,
#   0.0005253302762321573,
#   0.00016269057837355112],
#  ['Site4_Loc1_BF375_1',
#   'Site4_Loc1_BF375_2',
#   'Site4_Loc1_DF002_1',
#   'Site1_Loc4_AL116_1',
#   'Site1_Loc4_AL116_2'])

# %% [markdown]
# Site1_Loc4_DF002_2

# %%
df = pd.read_csv('Site1_Loc4_DF002_2.csv', delimiter = "      ",  encoding='ISO-8859-1')
column_names = ['Datum & tijd', 'Druk (cmH2O)', "Temperatuur"]
df.columns = column_names

# %%
plt.figure(figsize = (10, 6))
plt.subplot(121)
Patmo = 955

h, t = import_data(df, Patmo)
code = "Site1_Loc4_DF200_2"

plt.subplot(122)

r = 10/2/100 #radius of bore hole (m)
inv_aug(r, h, t, code)
# Out:
# angle -0.6469521630412463
# ([0.00021082596475959354,
#   7.94187408159181e-05,
#   4.156487682289258e-06,
#   0.0005253302762321573,
#   0.00016269057837355112,
#   0.0006492857016790994],
#  ['Site4_Loc1_BF375_1',
#   'Site4_Loc1_BF375_2',
#   'Site4_Loc1_DF002_1',
#   'Site1_Loc4_AL116_1',
#   'Site1_Loc4_AL116_2',
#   'Site1_Loc4_DF200_2'])

# %% [markdown]
# Site2_Loc1_AL116_1

# %%
df = pd.read_csv('Site2_loc1_AL116_1.csv', delimiter = "      ",  encoding='ISO-8859-1')
column_names = ['Datum & tijd', 'Druk (cmH2O)', "Temperatuur"]
df.columns = column_names

# %%
plt.figure(figsize = (10, 6))
plt.subplot(121)
Patmo = 955

h, t = import_data(df, Patmo)
code = "Site2_Loc1_AL116_1"

plt.subplot(122)

r = 10/2/100 #radius of bore hole (m)
inv_aug(r, h, t, code)
# Out:
# angle -0.15825316362238515
# ([0.00021082596475959354,
#   7.94187408159181e-05,
#   4.156487682289258e-06,
#   0.0005253302762321573,
#   0.00016269057837355112,
#   0.0006492857016790994,
#   0.00015881763238813858],
#  ['Site4_Loc1_BF375_1',
#   'Site4_Loc1_BF375_2',
#   'Site4_Loc1_DF002_1',
#   'Site1_Loc4_AL116_1',
#   'Site1_Loc4_AL116_2',
#   'Site1_Loc4_DF200_2',
#   'Site2_Loc1_AL116_1'])

# %% [markdown]
# Site2_loc1_AL116_2

# %%
df = pd.read_csv('Site2_loc1_AL116_2.csv', delimiter = "      ",  encoding='ISO-8859-1')
column_names = ['Datum & tijd', 'Druk (cmH2O)', "Temperatuur"]
df.columns = column_names

# %%
plt.figure(figsize = (10, 6))
plt.subplot(121)
Patmo = 955

h, t = import_data(df[:-5], Patmo)
code = "Site2_Loc1_AL116_2"

plt.subplot(122)

r = 10/2/100 #radius of bore hole (m)
inv_aug(r, h, t, code)
# Out:
# angle -0.08043220446050263
# ([0.00021082596475959354,
#   7.94187408159181e-05,
#   4.156487682289258e-06,
#   0.0005253302762321573,
#   0.00016269057837355112,
#   0.0006492857016790994,
#   0.00015881763238813858,
#   8.071894359076808e-05],
#  ['Site4_Loc1_BF375_1',
#   'Site4_Loc1_BF375_2',
#   'Site4_Loc1_DF002_1',
#   'Site1_Loc4_AL116_1',
#   'Site1_Loc4_AL116_2',
#   'Site1_Loc4_DF200_2',
#   'Site2_Loc1_AL116_1',
#   'Site2_Loc1_AL116_2'])

# %% [markdown]
# Site2_loc1_AL116_3

# %%
df = pd.read_csv('Site2_loc1_AL116_3.csv', delimiter = "      ",  encoding='ISO-8859-1')
column_names = ['Datum & tijd', 'Druk (cmH2O)', "Temperatuur"]
df.columns = column_names

# %%
plt.figure(figsize = (10, 6))
plt.subplot(121)
Patmo = 955

h, t = import_data(df[:-5], Patmo)
code = "Site2_Loc1_AL116_3"

plt.subplot(122)

r = 10/2/100 #radius of bore hole (m)
inv_aug(r, h, t, code)
# Out:
# angle -0.06767213876416037
# ([0.00021082596475959354,
#   7.94187408159181e-05,
#   4.156487682289258e-06,
#   0.0005253302762321573,
#   0.00016269057837355112,
#   0.0006492857016790994,
#   0.00015881763238813858,
#   8.071894359076808e-05,
#   6.79133754945591e-05],
#  ['Site4_Loc1_BF375_1',
#   'Site4_Loc1_BF375_2',
#   'Site4_Loc1_DF002_1',
#   'Site1_Loc4_AL116_1',
#   'Site1_Loc4_AL116_2',
#   'Site1_Loc4_DF200_2',
#   'Site2_Loc1_AL116_1',
#   'Site2_Loc1_AL116_2',
#   'Site2_Loc1_AL116_3'])

# %% [markdown]
# Site2_Loc1_DF002_1

# %%
df = pd.read_csv('Site2_loc1_DF002_1.csv', delimiter = "      ",  encoding='ISO-8859-1')
column_names = ['Datum & tijd', 'Druk (cmH2O)', "Temperatuur"]
df.columns = column_names

# %%
plt.figure(figsize = (10, 6))
plt.subplot(121)
Patmo = 955

h, t = import_data(df[:-5], Patmo)
code = "Site2_Loc1_DF002_1"

plt.subplot(122)

r = 10/2/100 #radius of bore hole (m)
inv_aug(r, h, t, code)
# Out:
# angle -0.21991908982440583
# ([0.00021082596475959354,
#   7.94187408159181e-05,
#   4.156487682289258e-06,
#   0.0005253302762321573,
#   0.00016269057837355112,
#   0.0006492857016790994,
#   0.00015881763238813858,
#   8.071894359076808e-05,
#   6.79133754945591e-05,
#   0.0002207040356640821],
#  ['Site4_Loc1_BF375_1',
#   'Site4_Loc1_BF375_2',
#   'Site4_Loc1_DF002_1',
#   'Site1_Loc4_AL116_1',
#   'Site1_Loc4_AL116_2',
#   'Site1_Loc4_DF200_2',
#   'Site2_Loc1_AL116_1',
#   'Site2_Loc1_AL116_2',
#   'Site2_Loc1_AL116_3',
#   'Site2_Loc1_DF002_1'])

# %% [markdown]
# Site2_Loc1_DF002_2

# %%
df = pd.read_csv('Site2_loc1_DF002_2.csv', delimiter = "      ",  encoding='ISO-8859-1')
column_names = ['Datum & tijd', 'Druk (cmH2O)', "Temperatuur"]
df.columns = column_names

# %%
plt.figure(figsize = (10, 6))
plt.subplot(121)
Patmo = 955

h, t = import_data(df[:-10], Patmo)
code = "Site2_Loc1_DF002_2"

plt.subplot(122)

r = 10/2/100 #radius of bore hole (m)
inv_aug(r, h, t, code)
# Out:
# angle -0.10958874562598318
# ([0.00021082596475959354,
#   7.94187408159181e-05,
#   4.156487682289258e-06,
#   0.0005253302762321573,
#   0.00016269057837355112,
#   0.0006492857016790994,
#   0.00015881763238813858,
#   8.071894359076808e-05,
#   6.79133754945591e-05,
#   0.0002207040356640821,
#   0.00010997948908742784],
#  ['Site4_Loc1_BF375_1',
#   'Site4_Loc1_BF375_2',
#   'Site4_Loc1_DF002_1',
#   'Site1_Loc4_AL116_1',
#   'Site1_Loc4_AL116_2',
#   'Site1_Loc4_DF200_2',
#   'Site2_Loc1_AL116_1',
#   'Site2_Loc1_AL116_2',
#   'Site2_Loc1_AL116_3',
#   'Site2_Loc1_DF002_1',
#   'Site2_Loc1_DF002_2'])

# %% [markdown]
# Site2_Loc1_DF002_3

# %%
df = pd.read_csv('Site2_loc1_DF002_3.csv', delimiter = "      ",  encoding='ISO-8859-1')
column_names = ['Datum & tijd', 'Druk (cmH2O)', "Temperatuur"]
df.columns = column_names

# %%
plt.figure(figsize = (10, 6))
plt.subplot(121)
Patmo = 955

h, t = import_data(df[:-50], Patmo)
code = "Site2_Loc1_DF002_3"

plt.subplot(122)

r = 10/2/100 #radius of bore hole (m)
inv_aug(r, h, t, code)
# Out:
# angle -0.05842282322502385
# ([0.00021082596475959354,
#   7.94187408159181e-05,
#   4.156487682289258e-06,
#   0.0005253302762321573,
#   0.00016269057837355112,
#   0.0006492857016790994,
#   0.00015881763238813858,
#   8.071894359076808e-05,
#   6.79133754945591e-05,
#   0.0002207040356640821,
#   0.00010997948908742784,
#   5.863108117639902e-05],
#  ['Site4_Loc1_BF375_1',
#   'Site4_Loc1_BF375_2',
#   'Site4_Loc1_DF002_1',
#   'Site1_Loc4_AL116_1',
#   'Site1_Loc4_AL116_2',
#   'Site1_Loc4_DF200_2',
#   'Site2_Loc1_AL116_1',
#   'Site2_Loc1_AL116_2',
#   'Site2_Loc1_AL116_3',
#   'Site2_Loc1_DF002_1',
#   'Site2_Loc1_DF002_2',
#   'Site2_Loc1_DF002_3'])

# %% [markdown]
# Site2_Loc6_AL116_1

# %%
df = pd.read_csv('Site2_loc6_AL116_1.csv', delimiter = "      ",  encoding='ISO-8859-1')
column_names = ['Datum & tijd', 'Druk (cmH2O)', "Temperatuur"]
df.columns = column_names

# %%
plt.figure(figsize = (10, 6))
plt.subplot(121)
Patmo = 950

h, t = import_data(df, Patmo)
code = "Site2_Loc6_AL116_1"

plt.subplot(122)

r = 10/2/100 #radius of bore hole (m)
inv_aug(r, h, t, code)
# Out:
# angle -0.7516512809248626
# ([0.00021082596475959354,
#   7.94187408159181e-05,
#   4.156487682289258e-06,
#   0.0005253302762321573,
#   0.00016269057837355112,
#   0.0006492857016790994,
#   0.00015881763238813858,
#   8.071894359076808e-05,
#   6.79133754945591e-05,
#   0.0002207040356640821,
#   0.00010997948908742784,
#   5.863108117639902e-05,
#   0.0007543736836055774],
#  ['Site4_Loc1_BF375_1',
#   'Site4_Loc1_BF375_2',
#   'Site4_Loc1_DF002_1',
#   'Site1_Loc4_AL116_1',
#   'Site1_Loc4_AL116_2',
#   'Site1_Loc4_DF200_2',
#   'Site2_Loc1_AL116_1',
#   'Site2_Loc1_AL116_2',
#   'Site2_Loc1_AL116_3',
#   'Site2_Loc1_DF002_1',
#   'Site2_Loc1_DF002_2',
#   'Site2_Loc1_DF002_3',
#   'Site2_Loc6_AL116_1'])

# %% [markdown]
# Site2_loc6_AL116_2

# %%
df = pd.read_csv('Site2_loc6_AL116_2.csv', delimiter = "      ",  encoding='ISO-8859-1')
column_names = ['Datum & tijd', 'Druk (cmH2O)', "Temperatuur"]
df.columns = column_names

# %%
plt.figure(figsize = (10, 6))
plt.subplot(121)
Patmo = 950

h, t = import_data(df, Patmo)
code = "Site2_Loc6_AL116_2"

plt.subplot(122)

r = 10/2/100 #radius of bore hole (m)
inv_aug(r, h, t, code)
# Out:
# angle -0.3763910635923234
# ([0.00021082596475959354,
#   7.94187408159181e-05,
#   4.156487682289258e-06,
#   0.0005253302762321573,
#   0.00016269057837355112,
#   0.0006492857016790994,
#   0.00015881763238813858,
#   8.071894359076808e-05,
#   6.79133754945591e-05,
#   0.0002207040356640821,
#   0.00010997948908742784,
#   5.863108117639902e-05,
#   0.0007543736836055774,
#   0.0003777380755548871],
#  ['Site4_Loc1_BF375_1',
#   'Site4_Loc1_BF375_2',
#   'Site4_Loc1_DF002_1',
#   'Site1_Loc4_AL116_1',
#   'Site1_Loc4_AL116_2',
#   'Site1_Loc4_DF200_2',
#   'Site2_Loc1_AL116_1',
#   'Site2_Loc1_AL116_2',
#   'Site2_Loc1_AL116_3',
#   'Site2_Loc1_DF002_1',
#   'Site2_Loc1_DF002_2',
#   'Site2_Loc1_DF002_3',
#   'Site2_Loc6_AL116_1',
#   'Site2_Loc6_AL116_2'])

# %% [markdown]
# Site2_Loc6_AL116_3

# %%
df = pd.read_csv('Site2_loc6_AL116_3.csv', delimiter = "      ",  encoding='ISO-8859-1')
column_names = ['Datum & tijd', 'Druk (cmH2O)', "Temperatuur"]
df.columns = column_names

# %%
plt.figure(figsize = (10, 6))
plt.subplot(121)
Patmo = 950

h, t = import_data(df, Patmo)
code = "Site2_Loc6_AL116_3"

plt.subplot(122)

r = 10/2/100 #radius of bore hole (m)
inv_aug(r, h, t, code)
# Out:
# angle -0.3649199557526738
# ([0.00021082596475959354,
#   7.94187408159181e-05,
#   4.156487682289258e-06,
#   0.0005253302762321573,
#   0.00016269057837355112,
#   0.0006492857016790994,
#   0.00015881763238813858,
#   8.071894359076808e-05,
#   6.79133754945591e-05,
#   0.0002207040356640821,
#   0.00010997948908742784,
#   5.863108117639902e-05,
#   0.0007543736836055774,
#   0.0003777380755548871,
#   0.0003662255991882395],
#  ['Site4_Loc1_BF375_1',
#   'Site4_Loc1_BF375_2',
#   'Site4_Loc1_DF002_1',
#   'Site1_Loc4_AL116_1',
#   'Site1_Loc4_AL116_2',
#   'Site1_Loc4_DF200_2',
#   'Site2_Loc1_AL116_1',
#   'Site2_Loc1_AL116_2',
#   'Site2_Loc1_AL116_3',
#   'Site2_Loc1_DF002_1',
#   'Site2_Loc1_DF002_2',
#   'Site2_Loc1_DF002_3',
#   'Site2_Loc6_AL116_1',
#   'Site2_Loc6_AL116_2',
#   'Site2_Loc6_AL116_3'])

# %% [markdown]
# Site2_loc6_DF002_1

# %%
df = pd.read_csv('Site2_loc6_DF002_1.csv', delimiter = "      ",  encoding='ISO-8859-1')
column_names = ['Datum & tijd', 'Druk (cmH2O)', "Temperatuur"]
df.columns = column_names

# %%
plt.figure(figsize = (10, 6))
plt.subplot(121)
Patmo = 950

h, t = import_data(df, Patmo)
code = "Site2_Loc6_DF002_1"

plt.subplot(122)

r = 10/2/100 #radius of bore hole (m)
inv_aug(r, h, t, code)
# Out:
# angle -0.2658979638787863
# ([0.00021082596475959354,
#   7.94187408159181e-05,
#   4.156487682289258e-06,
#   0.0005253302762321573,
#   0.00016269057837355112,
#   0.0006492857016790994,
#   0.00015881763238813858,
#   8.071894359076808e-05,
#   6.79133754945591e-05,
#   0.0002207040356640821,
#   0.00010997948908742784,
#   5.863108117639902e-05,
#   0.0007543736836055774,
#   0.0003777380755548871,
#   0.0003662255991882395,
#   0.0002668476249818098],
#  ['Site4_Loc1_BF375_1',
#   'Site4_Loc1_BF375_2',
#   'Site4_Loc1_DF002_1',
#   'Site1_Loc4_AL116_1',
#   'Site1_Loc4_AL116_2',
#   'Site1_Loc4_DF200_2',
#   'Site2_Loc1_AL116_1',
#   'Site2_Loc1_AL116_2',
#   'Site2_Loc1_AL116_3',
#   'Site2_Loc1_DF002_1',
#   'Site2_Loc1_DF002_2',
#   'Site2_Loc1_DF002_3',
#   'Site2_Loc6_AL116_1',
#   'Site2_Loc6_AL116_2',
#   'Site2_Loc6_AL116_3',
#   'Site2_Loc6_DF002_1'])

# %% [markdown]
# Site2_Loc6_DF002_2

# %%
df = pd.read_csv('Site2_loc6_DF002_2.csv', delimiter = "      ",  encoding='ISO-8859-1')
column_names = ['Datum & tijd', 'Druk (cmH2O)', "Temperatuur"]
df.columns = column_names

# %%
plt.figure(figsize = (10, 6))
plt.subplot(121)
Patmo = 950

h, t = import_data(df, Patmo)
code = "Site2_Loc6_DF002_2"

plt.subplot(122)

r = 10/2/100 #radius of bore hole (m)
inv_aug(r, h, t, code)
# Out:
# angle -0.4025770372772023
# ([0.00021082596475959354,
#   7.94187408159181e-05,
#   4.156487682289258e-06,
#   0.0005253302762321573,
#   0.00016269057837355112,
#   0.0006492857016790994,
#   0.00015881763238813858,
#   8.071894359076808e-05,
#   6.79133754945591e-05,
#   0.0002207040356640821,
#   0.00010997948908742784,
#   5.863108117639902e-05,
#   0.0007543736836055774,
#   0.0003777380755548871,
#   0.0003662255991882395,
#   0.0002668476249818098,
#   0.0004040185992833251],
#  ['Site4_Loc1_BF375_1',
#   'Site4_Loc1_BF375_2',
#   'Site4_Loc1_DF002_1',
#   'Site1_Loc4_AL116_1',
#   'Site1_Loc4_AL116_2',
#   'Site1_Loc4_DF200_2',
#   'Site2_Loc1_AL116_1',
#   'Site2_Loc1_AL116_2',
#   'Site2_Loc1_AL116_3',
#   'Site2_Loc1_DF002_1',
#   'Site2_Loc1_DF002_2',
#   'Site2_Loc1_DF002_3',
#   'Site2_Loc6_AL116_1',
#   'Site2_Loc6_AL116_2',
#   'Site2_Loc6_AL116_3',
#   'Site2_Loc6_DF002_1',
#   'Site2_Loc6_DF002_2'])

# %% [markdown]
# Site2_Loc6_D002_3

# %%
df = pd.read_csv('Site2_loc6_DF002_3.csv', delimiter = "      ",  encoding='ISO-8859-1')
column_names = ['Datum & tijd', 'Druk (cmH2O)', "Temperatuur"]
df.columns = column_names

# %%
plt.figure(figsize = (10, 6))
plt.subplot(121)
Patmo = 950

h, t = import_data(df, Patmo)
code = "Site2_Loc6_DF002_3"

plt.subplot(122)

r = 10/2/100 #radius of bore hole (m)
inv_aug(r, h, t, code)
# Out:
# angle -0.27026468141261156
# ([0.00021082596475959354,
#   7.94187408159181e-05,
#   4.156487682289258e-06,
#   0.0005253302762321573,
#   0.00016269057837355112,
#   0.0006492857016790994,
#   0.00015881763238813858,
#   8.071894359076808e-05,
#   6.79133754945591e-05,
#   0.0002207040356640821,
#   0.00010997948908742784,
#   5.863108117639902e-05,
#   0.0007543736836055774,
#   0.0003777380755548871,
#   0.0003662255991882395,
#   0.0002668476249818098,
#   0.0004040185992833251,
#   0.0002712300028347941],
#  ['Site4_Loc1_BF375_1',
#   'Site4_Loc1_BF375_2',
#   'Site4_Loc1_DF002_1',
#   'Site1_Loc4_AL116_1',
#   'Site1_Loc4_AL116_2',
#   'Site1_Loc4_DF200_2',
#   'Site2_Loc1_AL116_1',
#   'Site2_Loc1_AL116_2',
#   'Site2_Loc1_AL116_3',
#   'Site2_Loc1_DF002_1',
#   'Site2_Loc1_DF002_2',
#   'Site2_Loc1_DF002_3',
#   'Site2_Loc6_AL116_1',
#   'Site2_Loc6_AL116_2',
#   'Site2_Loc6_AL116_3',
#   'Site2_Loc6_DF002_1',
#   'Site2_Loc6_DF002_2',
#   'Site2_Loc6_DF002_3'])

# %% [markdown]
# Site3_Loc1_1

# %%
df = pd.read_csv('Site3_loc1_AL116_1.csv', delimiter = "      ",  encoding='ISO-8859-1')
column_names = ['Datum & tijd', 'Druk (cmH2O)', "Temperatuur"]
df.columns = column_names

# %%
plt.figure(figsize = (10, 6))
plt.subplot(121)
Patmo = 950

h, t = import_data(df, Patmo)
code = "Site3_Loc1_AL116_1"

plt.subplot(122)

r = 10/2/100 #radius of bore hole (m)
inv_aug(r, h, t, code)
# Out:
# angle -0.30875287735109924
# ([0.00021082596475959354,
#   7.94187408159181e-05,
#   4.156487682289258e-06,
#   0.0005253302762321573,
#   0.00016269057837355112,
#   0.0006492857016790994,
#   0.00015881763238813858,
#   8.071894359076808e-05,
#   6.79133754945591e-05,
#   0.0002207040356640821,
#   0.00010997948908742784,
#   5.863108117639902e-05,
#   0.0007543736836055774,
#   0.0003777380755548871,
#   0.0003662255991882395,
#   0.0002668476249818098,
#   0.0004040185992833251,
#   0.0002712300028347941,
#   0.0003098563706534051],
#  ['Site4_Loc1_BF375_1',
#   'Site4_Loc1_BF375_2',
#   'Site4_Loc1_DF002_1',
#   'Site1_Loc4_AL116_1',
#   'Site1_Loc4_AL116_2',
#   'Site1_Loc4_DF200_2',
#   'Site2_Loc1_AL116_1',
#   'Site2_Loc1_AL116_2',
#   'Site2_Loc1_AL116_3',
#   'Site2_Loc1_DF002_1',
#   'Site2_Loc1_DF002_2',
#   'Site2_Loc1_DF002_3',
#   'Site2_Loc6_AL116_1',
#   'Site2_Loc6_AL116_2',
#   'Site2_Loc6_AL116_3',
#   'Site2_Loc6_DF002_1',
#   'Site2_Loc6_DF002_2',
#   'Site2_Loc6_DF002_3',
#   'Site3_Loc1_AL116_1'])

# %%
df = pd.read_csv('Site3_loc1_AL116_2.csv', delimiter = "      ",  encoding='ISO-8859-1')
column_names = ['Datum & tijd', 'Druk (cmH2O)', "Temperatuur"]
df.columns = column_names

# %%
plt.figure(figsize = (10, 6))
plt.subplot(121)
Patmo = 950

h, t = import_data(df, Patmo)
code = "Site3_Loc1_AL116_2"

plt.subplot(122)

r = 10/2/100 #radius of bore hole (m)
inv_aug(r, h, t, code)
# Out:
# angle -0.2201677687420335
# ([0.00021082596475959354,
#   7.94187408159181e-05,
#   4.156487682289258e-06,
#   0.0005253302762321573,
#   0.00016269057837355112,
#   0.0006492857016790994,
#   0.00015881763238813858,
#   8.071894359076808e-05,
#   6.79133754945591e-05,
#   0.0002207040356640821,
#   0.00010997948908742784,
#   5.863108117639902e-05,
#   0.0007543736836055774,
#   0.0003777380755548871,
#   0.0003662255991882395,
#   0.0002668476249818098,
#   0.0004040185992833251,
#   0.0002712300028347941,
#   0.0003098563706534051,
#   0.0002209536046338748],
#  ['Site4_Loc1_BF375_1',
#   'Site4_Loc1_BF375_2',
#   'Site4_Loc1_DF002_1',
#   'Site1_Loc4_AL116_1',
#   'Site1_Loc4_AL116_2',
#   'Site1_Loc4_DF200_2',
#   'Site2_Loc1_AL116_1',
#   'Site2_Loc1_AL116_2',
#   'Site2_Loc1_AL116_3',
#   'Site2_Loc1_DF002_1',
#   'Site2_Loc1_DF002_2',
#   'Site2_Loc1_DF002_3',
#   'Site2_Loc6_AL116_1',
#   'Site2_Loc6_AL116_2',
#   'Site2_Loc6_AL116_3',
#   'Site2_Loc6_DF002_1',
#   'Site2_Loc6_DF002_2',
#   'Site2_Loc6_DF002_3',
#   'Site3_Loc1_AL116_1',
#   'Site3_Loc1_AL116_2'])

# %%
df = pd.read_csv('Site3_loc1_AL116_2.csv', delimiter = "      ",  encoding='ISO-8859-1')
column_names = ['Datum & tijd', 'Druk (cmH2O)', "Temperatuur"]
df.columns = column_names

# %%
plt.figure(figsize = (10, 6))
plt.subplot(121)
Patmo = 950

h, t = import_data(df, Patmo)
code = "Site3_Loc1_AL116_3"

plt.subplot(122)

r = 10/2/100 #radius of bore hole (m)
inv_aug(r, h, t, code)
# Out:
# angle -0.2201677687420335
# ([0.00021082596475959354,
#   7.94187408159181e-05,
#   4.156487682289258e-06,
#   0.0005253302762321573,
#   0.00016269057837355112,
#   0.0006492857016790994,
#   0.00015881763238813858,
#   8.071894359076808e-05,
#   6.79133754945591e-05,
#   0.0002207040356640821,
#   0.00010997948908742784,
#   5.863108117639902e-05,
#   0.0007543736836055774,
#   0.0003777380755548871,
#   0.0003662255991882395,
#   0.0002668476249818098,
#   0.0004040185992833251,
#   0.0002712300028347941,
#   0.0003098563706534051,
#   0.0002209536046338748,
#   0.0002209536046338748],
#  ['Site4_Loc1_BF375_1',
#   'Site4_Loc1_BF375_2',
#   'Site4_Loc1_DF002_1',
#   'Site1_Loc4_AL116_1',
#   'Site1_Loc4_AL116_2',
#   'Site1_Loc4_DF200_2',
#   'Site2_Loc1_AL116_1',
#   'Site2_Loc1_AL116_2',
#   'Site2_Loc1_AL116_3',
#   'Site2_Loc1_DF002_1',
#   'Site2_Loc1_DF002_2',
#   'Site2_Loc1_DF002_3',
#   'Site2_Loc6_AL116_1',
#   'Site2_Loc6_AL116_2',
#   'Site2_Loc6_AL116_3',
#   'Site2_Loc6_DF002_1',
#   'Site2_Loc6_DF002_2',
#   'Site2_Loc6_DF002_3',
#   'Site3_Loc1_AL116_1',
#   'Site3_Loc1_AL116_2',
#   'Site3_Loc1_AL116_3'])

# %%
df = pd.read_csv('Site3_loc1_DF002_1.csv', delimiter = "      ",  encoding='ISO-8859-1')
column_names = ['Datum & tijd', 'Druk (cmH2O)', "Temperatuur"]
df.columns = column_names

# %%
plt.figure(figsize = (10, 6))
plt.subplot(121)
Patmo = 950

h, t = import_data(df, Patmo)
code = "Site3_Loc1_DF002_1"

plt.subplot(122)

r = 10/2/100 #radius of bore hole (m)
inv_aug(r, h, t, code)
# Out:
# angle -0.16040801486416187
# ([0.00021082596475959354,
#   7.94187408159181e-05,
#   4.156487682289258e-06,
#   0.0005253302762321573,
#   0.00016269057837355112,
#   0.0006492857016790994,
#   0.00015881763238813858,
#   8.071894359076808e-05,
#   6.79133754945591e-05,
#   0.0002207040356640821,
#   0.00010997948908742784,
#   5.863108117639902e-05,
#   0.0007543736836055774,
#   0.0003777380755548871,
#   0.0003662255991882395,
#   0.0002668476249818098,
#   0.0004040185992833251,
#   0.0002712300028347941,
#   0.0003098563706534051,
#   0.0002209536046338748,
#   0.0002209536046338748,
#   0.000160980180932465],
#  ['Site4_Loc1_BF375_1',
#   'Site4_Loc1_BF375_2',
#   'Site4_Loc1_DF002_1',
#   'Site1_Loc4_AL116_1',
#   'Site1_Loc4_AL116_2',
#   'Site1_Loc4_DF200_2',
#   'Site2_Loc1_AL116_1',
#   'Site2_Loc1_AL116_2',
#   'Site2_Loc1_AL116_3',
#   'Site2_Loc1_DF002_1',
#   'Site2_Loc1_DF002_2',
#   'Site2_Loc1_DF002_3',
#   'Site2_Loc6_AL116_1',
#   'Site2_Loc6_AL116_2',
#   'Site2_Loc6_AL116_3',
#   'Site2_Loc6_DF002_1',
#   'Site2_Loc6_DF002_2',
#   'Site2_Loc6_DF002_3',
#   'Site3_Loc1_AL116_1',
#   'Site3_Loc1_AL116_2',
#   'Site3_Loc1_AL116_3',
#   'Site3_Loc1_DF002_1'])

# %%
df = pd.read_csv('Site3_loc1_DF002_2.csv', delimiter = "      ",  encoding='ISO-8859-1')
column_names = ['Datum & tijd', 'Druk (cmH2O)', "Temperatuur"]
df.columns = column_names

# %%
plt.figure(figsize = (10, 6))
plt.subplot(121)
Patmo = 950

h, t = import_data(df, Patmo)
code = "Site3_Loc1_DF002_2"

plt.subplot(122)

r = 10/2/100 #radius of bore hole (m)
inv_aug(r, h[:-20], t[:-20], code)
# Out:
# angle -0.07393601773255538
# ([0.00021082596475959354,
#   7.94187408159181e-05,
#   4.156487682289258e-06,
#   0.0005253302762321573,
#   0.00016269057837355112,
#   0.0006492857016790994,
#   0.00015881763238813858,
#   8.071894359076808e-05,
#   6.79133754945591e-05,
#   0.0002207040356640821,
#   0.00010997948908742784,
#   5.863108117639902e-05,
#   0.0007543736836055774,
#   0.0003777380755548871,
#   0.0003662255991882395,
#   0.0002668476249818098,
#   0.0004040185992833251,
#   0.0002712300028347941,
#   0.0003098563706534051,
#   0.0002209536046338748,
#   0.0002209536046338748,
#   0.000160980180932465,
#   7.419959053741125e-05],
#  ['Site4_Loc1_BF375_1',
#   'Site4_Loc1_BF375_2',
#   'Site4_Loc1_DF002_1',
#   'Site1_Loc4_AL116_1',
#   'Site1_Loc4_AL116_2',
#   'Site1_Loc4_DF200_2',
#   'Site2_Loc1_AL116_1',
#   'Site2_Loc1_AL116_2',
#   'Site2_Loc1_AL116_3',
#   'Site2_Loc1_DF002_1',
#   'Site2_Loc1_DF002_2',
#   'Site2_Loc1_DF002_3',
#   'Site2_Loc6_AL116_1',
#   'Site2_Loc6_AL116_2',
#   'Site2_Loc6_AL116_3',
#   'Site2_Loc6_DF002_1',
#   'Site2_Loc6_DF002_2',
#   'Site2_Loc6_DF002_3',
#   'Site3_Loc1_AL116_1',
#   'Site3_Loc1_AL116_2',
#   'Site3_Loc1_AL116_3',
#   'Site3_Loc1_DF002_1',
#   'Site3_Loc1_DF002_2'])

# %%
df = pd.read_csv('Site3_loc1_DF002_3.csv', delimiter = "      ",  encoding='ISO-8859-1')
column_names = ['Datum & tijd', 'Druk (cmH2O)', "Temperatuur"]
df.columns = column_names

# %%
plt.figure(figsize = (10, 6))
plt.subplot(121)
Patmo = 950

h, t = import_data(df, Patmo)
code = "Site3_Loc1_DF002_3"

plt.subplot(122)

r = 10/2/100 #radius of bore hole (m)
inv_aug(r, h[:-10], t[:-10], code)
# Out:
# angle -0.06175481365993642
# ([0.00021082596475959354,
#   7.94187408159181e-05,
#   4.156487682289258e-06,
#   0.0005253302762321573,
#   0.00016269057837355112,
#   0.0006492857016790994,
#   0.00015881763238813858,
#   8.071894359076808e-05,
#   6.79133754945591e-05,
#   0.0002207040356640821,
#   0.00010997948908742784,
#   5.863108117639902e-05,
#   0.0007543736836055774,
#   0.0003777380755548871,
#   0.0003662255991882395,
#   0.0002668476249818098,
#   0.0004040185992833251,
#   0.0002712300028347941,
#   0.0003098563706534051,
#   0.0002209536046338748,
#   0.0002209536046338748,
#   0.000160980180932465,
#   7.419959053741125e-05,
#   6.197495156988425e-05],
#  ['Site4_Loc1_BF375_1',
#   'Site4_Loc1_BF375_2',
#   'Site4_Loc1_DF002_1',
#   'Site1_Loc4_AL116_1',
#   'Site1_Loc4_AL116_2',
#   'Site1_Loc4_DF200_2',
#   'Site2_Loc1_AL116_1',
#   'Site2_Loc1_AL116_2',
#   'Site2_Loc1_AL116_3',
#   'Site2_Loc1_DF002_1',
#   'Site2_Loc1_DF002_2',
#   'Site2_Loc1_DF002_3',
#   'Site2_Loc6_AL116_1',
#   'Site2_Loc6_AL116_2',
#   'Site2_Loc6_AL116_3',
#   'Site2_Loc6_DF002_1',
#   'Site2_Loc6_DF002_2',
#   'Site2_Loc6_DF002_3',
#   'Site3_Loc1_AL116_1',
#   'Site3_Loc1_AL116_2',
#   'Site3_Loc1_AL116_3',
#   'Site3_Loc1_DF002_1',
#   'Site3_Loc1_DF002_2',
#   'Site3_Loc1_DF002_3'])

# %%
df = pd.read_csv('Site3_Loc4_AL116_1.csv', delimiter = "      ",  encoding='ISO-8859-1')
column_names = ['Datum & tijd', 'Druk (cmH2O)', "Temperatuur"]
df.columns = column_names

# %%
plt.figure(figsize = (10, 6))
plt.subplot(121)
Patmo = 950

h, t = import_data(df[10:-10], Patmo)
code = "Site3_Loc4_AL116_1"

plt.subplot(122)

r = 10/2/100 #radius of bore hole (m)
inv_aug(r, h, t, code)
# Out:
# angle -0.05619347263836352
# ([0.00021082596475959354,
#   7.94187408159181e-05,
#   4.156487682289258e-06,
#   0.0005253302762321573,
#   0.00016269057837355112,
#   0.0006492857016790994,
#   0.00015881763238813858,
#   8.071894359076808e-05,
#   6.79133754945591e-05,
#   0.0002207040356640821,
#   0.00010997948908742784,
#   5.863108117639902e-05,
#   0.0007543736836055774,
#   0.0003777380755548871,
#   0.0003662255991882395,
#   0.0002668476249818098,
#   0.0004040185992833251,
#   0.0002712300028347941,
#   0.0003098563706534051,
#   0.0002209536046338748,
#   0.0002209536046338748,
#   0.000160980180932465,
#   7.419959053741125e-05,
#   6.197495156988425e-05,
#   5.639378223253935e-05],
#  ['Site4_Loc1_BF375_1',
#   'Site4_Loc1_BF375_2',
#   'Site4_Loc1_DF002_1',
#   'Site1_Loc4_AL116_1',
#   'Site1_Loc4_AL116_2',
#   'Site1_Loc4_DF200_2',
#   'Site2_Loc1_AL116_1',
#   'Site2_Loc1_AL116_2',
#   'Site2_Loc1_AL116_3',
#   'Site2_Loc1_DF002_1',
#   'Site2_Loc1_DF002_2',
#   'Site2_Loc1_DF002_3',
#   'Site2_Loc6_AL116_1',
#   'Site2_Loc6_AL116_2',
#   'Site2_Loc6_AL116_3',
#   'Site2_Loc6_DF002_1',
#   'Site2_Loc6_DF002_2',
#   'Site2_Loc6_DF002_3',
#   'Site3_Loc1_AL116_1',
#   'Site3_Loc1_AL116_2',
#   'Site3_Loc1_AL116_3',
#   'Site3_Loc1_DF002_1',
#   'Site3_Loc1_DF002_2',
#   'Site3_Loc1_DF002_3',
#   'Site3_Loc4_AL116_1'])

# %%
df = pd.read_csv('Site3_Loc4_AL116_2.csv', delimiter = "      ",  encoding='ISO-8859-1')
column_names = ['Datum & tijd', 'Druk (cmH2O)', "Temperatuur"]
df.columns = column_names

# %%
plt.figure(figsize = (10, 6))
plt.subplot(121)
Patmo = 950

h, t = import_data(df[:-60], Patmo)
code = "Site3_Loc4_AL116_2"

plt.subplot(122)

r = 10/2/100 #radius of bore hole (m)
inv_aug(r, h, t, code)
# Out:
# angle -0.05547360962205478
# ([0.00021082596475959354,
#   7.94187408159181e-05,
#   4.156487682289258e-06,
#   0.0005253302762321573,
#   0.00016269057837355112,
#   0.0006492857016790994,
#   0.00015881763238813858,
#   8.071894359076808e-05,
#   6.79133754945591e-05,
#   0.0002207040356640821,
#   0.00010997948908742784,
#   5.863108117639902e-05,
#   0.0007543736836055774,
#   0.0003777380755548871,
#   0.0003662255991882395,
#   0.0002668476249818098,
#   0.0004040185992833251,
#   0.0002712300028347941,
#   0.0003098563706534051,
#   0.0002209536046338748,
#   0.0002209536046338748,
#   0.000160980180932465,
#   7.419959053741125e-05,
#   6.197495156988425e-05,
#   5.639378223253935e-05,
#   5.5671352708123385e-05],
#  ['Site4_Loc1_BF375_1',
#   'Site4_Loc1_BF375_2',
#   'Site4_Loc1_DF002_1',
#   'Site1_Loc4_AL116_1',
#   'Site1_Loc4_AL116_2',
#   'Site1_Loc4_DF200_2',
#   'Site2_Loc1_AL116_1',
#   'Site2_Loc1_AL116_2',
#   'Site2_Loc1_AL116_3',
#   'Site2_Loc1_DF002_1',
#   'Site2_Loc1_DF002_2',
#   'Site2_Loc1_DF002_3',
#   'Site2_Loc6_AL116_1',
#   'Site2_Loc6_AL116_2',
#   'Site2_Loc6_AL116_3',
#   'Site2_Loc6_DF002_1',
#   'Site2_Loc6_DF002_2',
#   'Site2_Loc6_DF002_3',
#   'Site3_Loc1_AL116_1',
#   'Site3_Loc1_AL116_2',
#   'Site3_Loc1_AL116_3',
#   'Site3_Loc1_DF002_1',
#   'Site3_Loc1_DF002_2',
#   'Site3_Loc1_DF002_3',
#   'Site3_Loc4_AL116_1',
#   'Site3_Loc4_AL116_2'])

# %%
df = pd.read_csv('Site3_Loc4_AL116_3.csv', delimiter = "      ",  encoding='ISO-8859-1')
column_names = ['Datum & tijd', 'Druk (cmH2O)', "Temperatuur"]
df.columns = column_names

# %%
plt.figure(figsize = (10, 6))
plt.subplot(121)
Patmo = 950

h, t = import_data(df[:-20], Patmo)
code = "Site3_Loc4_AL116_3"

plt.subplot(122)

r = 10/2/100 #radius of bore hole (m)
inv_aug(r, h, t, code)
# Out:
# angle -0.04836116265216434
# ([0.00021082596475959354,
#   7.94187408159181e-05,
#   4.156487682289258e-06,
#   0.0005253302762321573,
#   0.00016269057837355112,
#   0.0006492857016790994,
#   0.00015881763238813858,
#   8.071894359076808e-05,
#   6.79133754945591e-05,
#   0.0002207040356640821,
#   0.00010997948908742784,
#   5.863108117639902e-05,
#   0.0007543736836055774,
#   0.0003777380755548871,
#   0.0003662255991882395,
#   0.0002668476249818098,
#   0.0004040185992833251,
#   0.0002712300028347941,
#   0.0003098563706534051,
#   0.0002209536046338748,
#   0.0002209536046338748,
#   0.000160980180932465,
#   7.419959053741125e-05,
#   6.197495156988425e-05,
#   5.639378223253935e-05,
#   5.5671352708123385e-05,
#   4.853354883218015e-05],
#  ['Site4_Loc1_BF375_1',
#   'Site4_Loc1_BF375_2',
#   'Site4_Loc1_DF002_1',
#   'Site1_Loc4_AL116_1',
#   'Site1_Loc4_AL116_2',
#   'Site1_Loc4_DF200_2',
#   'Site2_Loc1_AL116_1',
#   'Site2_Loc1_AL116_2',
#   'Site2_Loc1_AL116_3',
#   'Site2_Loc1_DF002_1',
#   'Site2_Loc1_DF002_2',
#   'Site2_Loc1_DF002_3',
#   'Site2_Loc6_AL116_1',
#   'Site2_Loc6_AL116_2',
#   'Site2_Loc6_AL116_3',
#   'Site2_Loc6_DF002_1',
#   'Site2_Loc6_DF002_2',
#   'Site2_Loc6_DF002_3',
#   'Site3_Loc1_AL116_1',
#   'Site3_Loc1_AL116_2',
#   'Site3_Loc1_AL116_3',
#   'Site3_Loc1_DF002_1',
#   'Site3_Loc1_DF002_2',
#   'Site3_Loc1_DF002_3',
#   'Site3_Loc4_AL116_1',
#   'Site3_Loc4_AL116_2',
#   'Site3_Loc4_AL116_3'])

# %%
df = pd.read_csv('Site3_Loc4_DF002_1.csv', delimiter = "      ",  encoding='ISO-8859-1')
column_names = ['Datum & tijd', 'Druk (cmH2O)', "Temperatuur"]
df.columns = column_names

# %%
plt.figure(figsize = (10, 6))
plt.subplot(121)
Patmo = 950

h, t = import_data(df, Patmo)
code = "Site3_Loc4_DF002_1"

plt.subplot(122)

r = 10/2/100 #radius of bore hole (m)
inv_aug(r, h, t, code)
# Out:
# angle -0.02486269017541347
# ([0.00021082596475959354,
#   7.94187408159181e-05,
#   4.156487682289258e-06,
#   0.0005253302762321573,
#   0.00016269057837355112,
#   0.0006492857016790994,
#   0.00015881763238813858,
#   8.071894359076808e-05,
#   6.79133754945591e-05,
#   0.0002207040356640821,
#   0.00010997948908742784,
#   5.863108117639902e-05,
#   0.0007543736836055774,
#   0.0003777380755548871,
#   0.0003662255991882395,
#   0.0002668476249818098,
#   0.0004040185992833251,
#   0.0002712300028347941,
#   0.0003098563706534051,
#   0.0002209536046338748,
#   0.0002209536046338748,
#   0.000160980180932465,
#   7.419959053741125e-05,
#   6.197495156988425e-05,
#   5.639378223253935e-05,
#   5.5671352708123385e-05,
#   4.853354883218015e-05,
#   2.495131032280511e-05],
#  ['Site4_Loc1_BF375_1',
#   'Site4_Loc1_BF375_2',
#   'Site4_Loc1_DF002_1',
#   'Site1_Loc4_AL116_1',
#   'Site1_Loc4_AL116_2',
#   'Site1_Loc4_DF200_2',
#   'Site2_Loc1_AL116_1',
#   'Site2_Loc1_AL116_2',
#   'Site2_Loc1_AL116_3',
#   'Site2_Loc1_DF002_1',
#   'Site2_Loc1_DF002_2',
#   'Site2_Loc1_DF002_3',
#   'Site2_Loc6_AL116_1',
#   'Site2_Loc6_AL116_2',
#   'Site2_Loc6_AL116_3',
#   'Site2_Loc6_DF002_1',
#   'Site2_Loc6_DF002_2',
#   'Site2_Loc6_DF002_3',
#   'Site3_Loc1_AL116_1',
#   'Site3_Loc1_AL116_2',
#   'Site3_Loc1_AL116_3',
#   'Site3_Loc1_DF002_1',
#   'Site3_Loc1_DF002_2',
#   'Site3_Loc1_DF002_3',
#   'Site3_Loc4_AL116_1',
#   'Site3_Loc4_AL116_2',
#   'Site3_Loc4_AL116_3',
#   'Site3_Loc4_DF002_1'])

# %%
df = pd.read_csv('Site3_Loc4_DF002_2.csv', delimiter = "      ",  encoding='ISO-8859-1')
column_names = ['Datum & tijd', 'Druk (cmH2O)', "Temperatuur"]
df.columns = column_names

# %%
plt.figure(figsize = (10, 6))
plt.subplot(121)
Patmo = 950

h, t = import_data(df[:-20], Patmo)
code = "Site3_Loc4_DF002_2"

plt.subplot(122)

r = 10/2/100 #radius of bore hole (m)
inv_aug(r, h, t, code)
# Out:
# angle -0.0008877130159615168
# ([0.00021082596475959354,
#   7.94187408159181e-05,
#   4.156487682289258e-06,
#   0.0005253302762321573,
#   0.00016269057837355112,
#   0.0006492857016790994,
#   0.00015881763238813858,
#   8.071894359076808e-05,
#   6.79133754945591e-05,
#   0.0002207040356640821,
#   0.00010997948908742784,
#   5.863108117639902e-05,
#   0.0007543736836055774,
#   0.0003777380755548871,
#   0.0003662255991882395,
#   0.0002668476249818098,
#   0.0004040185992833251,
#   0.0002712300028347941,
#   0.0003098563706534051,
#   0.0002209536046338748,
#   0.0002209536046338748,
#   0.000160980180932465,
#   7.419959053741125e-05,
#   6.197495156988425e-05,
#   5.639378223253935e-05,
#   5.5671352708123385e-05,
#   4.853354883218015e-05,
#   2.495131032280511e-05,
#   8.908771091981877e-07],
#  ['Site4_Loc1_BF375_1',
#   'Site4_Loc1_BF375_2',
#   'Site4_Loc1_DF002_1',
#   'Site1_Loc4_AL116_1',
#   'Site1_Loc4_AL116_2',
#   'Site1_Loc4_DF200_2',
#   'Site2_Loc1_AL116_1',
#   'Site2_Loc1_AL116_2',
#   'Site2_Loc1_AL116_3',
#   'Site2_Loc1_DF002_1',
#   'Site2_Loc1_DF002_2',
#   'Site2_Loc1_DF002_3',
#   'Site2_Loc6_AL116_1',
#   'Site2_Loc6_AL116_2',
#   'Site2_Loc6_AL116_3',
#   'Site2_Loc6_DF002_1',
#   'Site2_Loc6_DF002_2',
#   'Site2_Loc6_DF002_3',
#   'Site3_Loc1_AL116_1',
#   'Site3_Loc1_AL116_2',
#   'Site3_Loc1_AL116_3',
#   'Site3_Loc1_DF002_1',
#   'Site3_Loc1_DF002_2',
#   'Site3_Loc1_DF002_3',
#   'Site3_Loc4_AL116_1',
#   'Site3_Loc4_AL116_2',
#   'Site3_Loc4_AL116_3',
#   'Site3_Loc4_DF002_1',
#   'Site3_Loc4_DF002_2'])

# %%
df = pd.read_csv('Site3_Loc4_DF002_3.csv', delimiter = "      ",  encoding='ISO-8859-1')
column_names = ['Datum & tijd', 'Druk (cmH2O)', "Temperatuur"]
df.columns = column_names

# %%
plt.figure(figsize = (10, 6))
plt.subplot(121)
Patmo = 950

h, t = import_data(df[:-20], Patmo)
code = "Site3_Loc4_DF002_3"

plt.subplot(122)

r = 10/2/100 #radius of bore hole (m)
inv_aug(r, h, t, code)
# Out:
# angle -0.0035335636203580414
# ([0.00021082596475959354,
#   7.94187408159181e-05,
#   4.156487682289258e-06,
#   0.0005253302762321573,
#   0.00016269057837355112,
#   0.0006492857016790994,
#   0.00015881763238813858,
#   8.071894359076808e-05,
#   6.79133754945591e-05,
#   0.0002207040356640821,
#   0.00010997948908742784,
#   5.863108117639902e-05,
#   0.0007543736836055774,
#   0.0003777380755548871,
#   0.0003662255991882395,
#   0.0002668476249818098,
#   0.0004040185992833251,
#   0.0002712300028347941,
#   0.0003098563706534051,
#   0.0002209536046338748,
#   0.0002209536046338748,
#   0.000160980180932465,
#   7.419959053741125e-05,
#   6.197495156988425e-05,
#   5.639378223253935e-05,
#   5.5671352708123385e-05,
#   4.853354883218015e-05,
#   2.495131032280511e-05,
#   8.908771091981877e-07,
#   3.5461583759723865e-06],
#  ['Site4_Loc1_BF375_1',
#   'Site4_Loc1_BF375_2',
#   'Site4_Loc1_DF002_1',
#   'Site1_Loc4_AL116_1',
#   'Site1_Loc4_AL116_2',
#   'Site1_Loc4_DF200_2',
#   'Site2_Loc1_AL116_1',
#   'Site2_Loc1_AL116_2',
#   'Site2_Loc1_AL116_3',
#   'Site2_Loc1_DF002_1',
#   'Site2_Loc1_DF002_2',
#   'Site2_Loc1_DF002_3',
#   'Site2_Loc6_AL116_1',
#   'Site2_Loc6_AL116_2',
#   'Site2_Loc6_AL116_3',
#   'Site2_Loc6_DF002_1',
#   'Site2_Loc6_DF002_2',
#   'Site2_Loc6_DF002_3',
#   'Site3_Loc1_AL116_1',
#   'Site3_Loc1_AL116_2',
#   'Site3_Loc1_AL116_3',
#   'Site3_Loc1_DF002_1',
#   'Site3_Loc1_DF002_2',
#   'Site3_Loc1_DF002_3',
#   'Site3_Loc4_AL116_1',
#   'Site3_Loc4_AL116_2',
#   'Site3_Loc4_AL116_3',
#   'Site3_Loc4_DF002_1',
#   'Site3_Loc4_DF002_2',
#   'Site3_Loc4_DF002_3'])

# %%
df = pd.read_csv('Site1_loc1_AL116_1.csv', delimiter = "      ",  encoding='ISO-8859-1')
column_names = ['Datum & tijd', 'Druk (cmH2O)', "Temperatuur"]
df.columns = column_names

# %%
plt.figure(figsize = (10, 6))
plt.subplot(121)
Patmo = 960

h, t = import_data(df, Patmo)
code = "Site1_Loc1_AL116_1"

plt.subplot(122)

r = 10/2/100 #radius of bore hole (m)
inv_aug(r, h, t, code)
# Out:
# angle -0.5856540034893689
# ([0.00021082596475959354,
#   7.94187408159181e-05,
#   4.156487682289258e-06,
#   0.0005253302762321573,
#   0.00016269057837355112,
#   0.0006492857016790994,
#   0.00015881763238813858,
#   8.071894359076808e-05,
#   6.79133754945591e-05,
#   0.0002207040356640821,
#   0.00010997948908742784,
#   5.863108117639902e-05,
#   0.0007543736836055774,
#   0.0003777380755548871,
#   0.0003662255991882395,
#   0.0002668476249818098,
#   0.0004040185992833251,
#   0.0002712300028347941,
#   0.0003098563706534051,
#   0.0002209536046338748,
#   0.0002209536046338748,
#   0.000160980180932465,
#   7.419959053741125e-05,
#   6.197495156988425e-05,
#   5.639378223253935e-05,
#   5.5671352708123385e-05,
#   4.853354883218015e-05,
#   2.495131032280511e-05,
#   8.908771091981877e-07,
#   3.5461583759723865e-06,
#   0.0005877619318173751],
#  ['Site4_Loc1_BF375_1',
#   'Site4_Loc1_BF375_2',
#   'Site4_Loc1_DF002_1',
#   'Site1_Loc4_AL116_1',
#   'Site1_Loc4_AL116_2',
#   'Site1_Loc4_DF200_2',
#   'Site2_Loc1_AL116_1',
#   'Site2_Loc1_AL116_2',
#   'Site2_Loc1_AL116_3',
#   'Site2_Loc1_DF002_1',
#   'Site2_Loc1_DF002_2',
#   'Site2_Loc1_DF002_3',
#   'Site2_Loc6_AL116_1',
#   'Site2_Loc6_AL116_2',
#   'Site2_Loc6_AL116_3',
#   'Site2_Loc6_DF002_1',
#   'Site2_Loc6_DF002_2',
#   'Site2_Loc6_DF002_3',
#   'Site3_Loc1_AL116_1',
#   'Site3_Loc1_AL116_2',
#   'Site3_Loc1_AL116_3',
#   'Site3_Loc1_DF002_1',
#   'Site3_Loc1_DF002_2',
#   'Site3_Loc1_DF002_3',
#   'Site3_Loc4_AL116_1',
#   'Site3_Loc4_AL116_2',
#   'Site3_Loc4_AL116_3',
#   'Site3_Loc4_DF002_1',
#   'Site3_Loc4_DF002_2',
#   'Site3_Loc4_DF002_3',
#   'Site1_Loc1_AL116_1'])

# %%
df = pd.read_csv('Site1_loc1_AL116_2.csv', delimiter = "      ",  encoding='ISO-8859-1')
column_names = ['Datum & tijd', 'Druk (cmH2O)', "Temperatuur"]
df.columns = column_names

# %%
plt.figure(figsize = (10, 6))
plt.subplot(121)
Patmo = 960

h, t = import_data(df, Patmo)
code = "Site1_Loc1_AL116_2"

plt.subplot(122)

r = 10/2/100 #radius of bore hole (m)
inv_aug(r, h, t, code)
# Out:
# angle -0.4148477385845915
# ([0.00021082596475959354,
#   7.94187408159181e-05,
#   4.156487682289258e-06,
#   0.0005253302762321573,
#   0.00016269057837355112,
#   0.0006492857016790994,
#   0.00015881763238813858,
#   8.071894359076808e-05,
#   6.79133754945591e-05,
#   0.0002207040356640821,
#   0.00010997948908742784,
#   5.863108117639902e-05,
#   0.0007543736836055774,
#   0.0003777380755548871,
#   0.0003662255991882395,
#   0.0002668476249818098,
#   0.0004040185992833251,
#   0.0002712300028347941,
#   0.0003098563706534051,
#   0.0002209536046338748,
#   0.0002209536046338748,
#   0.000160980180932465,
#   7.419959053741125e-05,
#   6.197495156988425e-05,
#   5.639378223253935e-05,
#   5.5671352708123385e-05,
#   4.853354883218015e-05,
#   2.495131032280511e-05,
#   8.908771091981877e-07,
#   3.5461583759723865e-06,
#   0.0005877619318173751,
#   0.00041633366398485106],
#  ['Site4_Loc1_BF375_1',
#   'Site4_Loc1_BF375_2',
#   'Site4_Loc1_DF002_1',
#   'Site1_Loc4_AL116_1',
#   'Site1_Loc4_AL116_2',
#   'Site1_Loc4_DF200_2',
#   'Site2_Loc1_AL116_1',
#   'Site2_Loc1_AL116_2',
#   'Site2_Loc1_AL116_3',
#   'Site2_Loc1_DF002_1',
#   'Site2_Loc1_DF002_2',
#   'Site2_Loc1_DF002_3',
#   'Site2_Loc6_AL116_1',
#   'Site2_Loc6_AL116_2',
#   'Site2_Loc6_AL116_3',
#   'Site2_Loc6_DF002_1',
#   'Site2_Loc6_DF002_2',
#   'Site2_Loc6_DF002_3',
#   'Site3_Loc1_AL116_1',
#   'Site3_Loc1_AL116_2',
#   'Site3_Loc1_AL116_3',
#   'Site3_Loc1_DF002_1',
#   'Site3_Loc1_DF002_2',
#   'Site3_Loc1_DF002_3',
#   'Site3_Loc4_AL116_1',
#   'Site3_Loc4_AL116_2',
#   'Site3_Loc4_AL116_3',
#   'Site3_Loc4_DF002_1',
#   'Site3_Loc4_DF002_2',
#   'Site3_Loc4_DF002_3',
#   'Site1_Loc1_AL116_1',
#   'Site1_Loc1_AL116_2'])

# %%
df = pd.read_csv('Site1_loc1_AL116_3.csv', delimiter = "      ",  encoding='ISO-8859-1')
column_names = ['Datum & tijd', 'Druk (cmH2O)', "Temperatuur"]
df.columns = column_names

# %%
plt.figure(figsize = (10, 6))
plt.subplot(121)
Patmo = 960

h, t = import_data(df, Patmo)
code = "Site1_Loc1_AL116_3"

plt.subplot(122)

r = 10/2/100 #radius of bore hole (m)
inv_aug(r, h, t, code)
# Out:
# angle -0.3552602586903225
# ([0.00021082596475959354,
#   7.94187408159181e-05,
#   4.156487682289258e-06,
#   0.0005253302762321573,
#   0.00016269057837355112,
#   0.0006492857016790994,
#   0.00015881763238813858,
#   8.071894359076808e-05,
#   6.79133754945591e-05,
#   0.0002207040356640821,
#   0.00010997948908742784,
#   5.863108117639902e-05,
#   0.0007543736836055774,
#   0.0003777380755548871,
#   0.0003662255991882395,
#   0.0002668476249818098,
#   0.0004040185992833251,
#   0.0002712300028347941,
#   0.0003098563706534051,
#   0.0002209536046338748,
#   0.0002209536046338748,
#   0.000160980180932465,
#   7.419959053741125e-05,
#   6.197495156988425e-05,
#   5.639378223253935e-05,
#   5.5671352708123385e-05,
#   4.853354883218015e-05,
#   2.495131032280511e-05,
#   8.908771091981877e-07,
#   3.5461583759723865e-06,
#   0.0005877619318173751,
#   0.00041633366398485106,
#   0.0003565310889419914],
#  ['Site4_Loc1_BF375_1',
#   'Site4_Loc1_BF375_2',
#   'Site4_Loc1_DF002_1',
#   'Site1_Loc4_AL116_1',
#   'Site1_Loc4_AL116_2',
#   'Site1_Loc4_DF200_2',
#   'Site2_Loc1_AL116_1',
#   'Site2_Loc1_AL116_2',
#   'Site2_Loc1_AL116_3',
#   'Site2_Loc1_DF002_1',
#   'Site2_Loc1_DF002_2',
#   'Site2_Loc1_DF002_3',
#   'Site2_Loc6_AL116_1',
#   'Site2_Loc6_AL116_2',
#   'Site2_Loc6_AL116_3',
#   'Site2_Loc6_DF002_1',
#   'Site2_Loc6_DF002_2',
#   'Site2_Loc6_DF002_3',
#   'Site3_Loc1_AL116_1',
#   'Site3_Loc1_AL116_2',
#   'Site3_Loc1_AL116_3',
#   'Site3_Loc1_DF002_1',
#   'Site3_Loc1_DF002_2',
#   'Site3_Loc1_DF002_3',
#   'Site3_Loc4_AL116_1',
#   'Site3_Loc4_AL116_2',
#   'Site3_Loc4_AL116_3',
#   'Site3_Loc4_DF002_1',
#   'Site3_Loc4_DF002_2',
#   'Site3_Loc4_DF002_3',
#   'Site1_Loc1_AL116_1',
#   'Site1_Loc1_AL116_2',
#   'Site1_Loc1_AL116_3'])

# %%
df = pd.read_csv('Site1_loc1_DF002_1.csv', delimiter = "      ",  encoding='ISO-8859-1')
column_names = ['Datum & tijd', 'Druk (cmH2O)', "Temperatuur"]
df.columns = column_names

# %%
plt.figure(figsize = (10, 6))
plt.subplot(121)
Patmo = 960

h, t = import_data(df, Patmo)
code = "Site1_Loc1_DF002_1"

plt.subplot(122)

r = 10/2/100 #radius of bore hole (m)
inv_aug(r, h, t, code)
# Out:
# angle -0.6553808649617072
# ([0.00021082596475959354,
#   7.94187408159181e-05,
#   4.156487682289258e-06,
#   0.0005253302762321573,
#   0.00016269057837355112,
#   0.0006492857016790994,
#   0.00015881763238813858,
#   8.071894359076808e-05,
#   6.79133754945591e-05,
#   0.0002207040356640821,
#   0.00010997948908742784,
#   5.863108117639902e-05,
#   0.0007543736836055774,
#   0.0003777380755548871,
#   0.0003662255991882395,
#   0.0002668476249818098,
#   0.0004040185992833251,
#   0.0002712300028347941,
#   0.0003098563706534051,
#   0.0002209536046338748,
#   0.0002209536046338748,
#   0.000160980180932465,
#   7.419959053741125e-05,
#   6.197495156988425e-05,
#   5.639378223253935e-05,
#   5.5671352708123385e-05,
#   4.853354883218015e-05,
#   2.495131032280511e-05,
#   8.908771091981877e-07,
#   3.5461583759723865e-06,
#   0.0005877619318173751,
#   0.00041633366398485106,
#   0.0003565310889419914,
#   0.0006577455388575203],
#  ['Site4_Loc1_BF375_1',
#   'Site4_Loc1_BF375_2',
#   'Site4_Loc1_DF002_1',
#   'Site1_Loc4_AL116_1',
#   'Site1_Loc4_AL116_2',
#   'Site1_Loc4_DF200_2',
#   'Site2_Loc1_AL116_1',
#   'Site2_Loc1_AL116_2',
#   'Site2_Loc1_AL116_3',
#   'Site2_Loc1_DF002_1',
#   'Site2_Loc1_DF002_2',
#   'Site2_Loc1_DF002_3',
#   'Site2_Loc6_AL116_1',
#   'Site2_Loc6_AL116_2',
#   'Site2_Loc6_AL116_3',
#   'Site2_Loc6_DF002_1',
#   'Site2_Loc6_DF002_2',
#   'Site2_Loc6_DF002_3',
#   'Site3_Loc1_AL116_1',
#   'Site3_Loc1_AL116_2',
#   'Site3_Loc1_AL116_3',
#   'Site3_Loc1_DF002_1',
#   'Site3_Loc1_DF002_2',
#   'Site3_Loc1_DF002_3',
#   'Site3_Loc4_AL116_1',
#   'Site3_Loc4_AL116_2',
#   'Site3_Loc4_AL116_3',
#   'Site3_Loc4_DF002_1',
#   'Site3_Loc4_DF002_2',
#   'Site3_Loc4_DF002_3',
#   'Site1_Loc1_AL116_1',
#   'Site1_Loc1_AL116_2',
#   'Site1_Loc1_AL116_3',
#   'Site1_Loc1_DF002_1'])

# %%
df = pd.read_csv('Site1_loc1_DF002_2.csv', delimiter = "      ",  encoding='ISO-8859-1')
column_names = ['Datum & tijd', 'Druk (cmH2O)', "Temperatuur"]
df.columns = column_names

# %%
plt.figure(figsize = (10, 6))
plt.subplot(121)
Patmo = 960

h, t = import_data(df, Patmo)
code = "Site1_Loc1_DF002_2"

plt.subplot(122)

r = 10/2/100 #radius of bore hole (m)
inv_aug(r, h, t, code)
# Out:
# angle -0.4682776679361102
# ([0.00021082596475959354,
#   7.94187408159181e-05,
#   4.156487682289258e-06,
#   0.0005253302762321573,
#   0.00016269057837355112,
#   0.0006492857016790994,
#   0.00015881763238813858,
#   8.071894359076808e-05,
#   6.79133754945591e-05,
#   0.0002207040356640821,
#   0.00010997948908742784,
#   5.863108117639902e-05,
#   0.0007543736836055774,
#   0.0003777380755548871,
#   0.0003662255991882395,
#   0.0002668476249818098,
#   0.0004040185992833251,
#   0.0002712300028347941,
#   0.0003098563706534051,
#   0.0002209536046338748,
#   0.0002209536046338748,
#   0.000160980180932465,
#   7.419959053741125e-05,
#   6.197495156988425e-05,
#   5.639378223253935e-05,
#   5.5671352708123385e-05,
#   4.853354883218015e-05,
#   2.495131032280511e-05,
#   8.908771091981877e-07,
#   3.5461583759723865e-06,
#   0.0005877619318173751,
#   0.00041633366398485106,
#   0.0003565310889419914,
#   0.0006577455388575203,
#   0.0004699572234151629],
#  ['Site4_Loc1_BF375_1',
#   'Site4_Loc1_BF375_2',
#   'Site4_Loc1_DF002_1',
#   'Site1_Loc4_AL116_1',
#   'Site1_Loc4_AL116_2',
#   'Site1_Loc4_DF200_2',
#   'Site2_Loc1_AL116_1',
#   'Site2_Loc1_AL116_2',
#   'Site2_Loc1_AL116_3',
#   'Site2_Loc1_DF002_1',
#   'Site2_Loc1_DF002_2',
#   'Site2_Loc1_DF002_3',
#   'Site2_Loc6_AL116_1',
#   'Site2_Loc6_AL116_2',
#   'Site2_Loc6_AL116_3',
#   'Site2_Loc6_DF002_1',
#   'Site2_Loc6_DF002_2',
#   'Site2_Loc6_DF002_3',
#   'Site3_Loc1_AL116_1',
#   'Site3_Loc1_AL116_2',
#   'Site3_Loc1_AL116_3',
#   'Site3_Loc1_DF002_1',
#   'Site3_Loc1_DF002_2',
#   'Site3_Loc1_DF002_3',
#   'Site3_Loc4_AL116_1',
#   'Site3_Loc4_AL116_2',
#   'Site3_Loc4_AL116_3',
#   'Site3_Loc4_DF002_1',
#   'Site3_Loc4_DF002_2',
#   'Site3_Loc4_DF002_3',
#   'Site1_Loc1_AL116_1',
#   'Site1_Loc1_AL116_2',
#   'Site1_Loc1_AL116_3',
#   'Site1_Loc1_DF002_1',
#   'Site1_Loc1_DF002_2'])

# %%
df = pd.read_csv('Site1_loc1_DF002_3.csv', delimiter = "      ",  encoding='ISO-8859-1')
column_names = ['Datum & tijd', 'Druk (cmH2O)', "Temperatuur"]
df.columns = column_names

# %%
plt.figure(figsize = (10, 6))
plt.subplot(121)
Patmo = 960

h, t = import_data(df, Patmo)
code = "Site1_Loc1_DF002_3"

plt.subplot(122)

r = 10/2/100 #radius of bore hole (m)
inv_aug(r, h, t, code)
# Out:
# angle -0.39508218839378556
# ([0.00021082596475959354,
#   7.94187408159181e-05,
#   4.156487682289258e-06,
#   0.0005253302762321573,
#   0.00016269057837355112,
#   0.0006492857016790994,
#   0.00015881763238813858,
#   8.071894359076808e-05,
#   6.79133754945591e-05,
#   0.0002207040356640821,
#   0.00010997948908742784,
#   5.863108117639902e-05,
#   0.0007543736836055774,
#   0.0003777380755548871,
#   0.0003662255991882395,
#   0.0002668476249818098,
#   0.0004040185992833251,
#   0.0002712300028347941,
#   0.0003098563706534051,
#   0.0002209536046338748,
#   0.0002209536046338748,
#   0.000160980180932465,
#   7.419959053741125e-05,
#   6.197495156988425e-05,
#   5.639378223253935e-05,
#   5.5671352708123385e-05,
#   4.853354883218015e-05,
#   2.495131032280511e-05,
#   8.908771091981877e-07,
#   3.5461583759723865e-06,
#   0.0005877619318173751,
#   0.00041633366398485106,
#   0.0003565310889419914,
#   0.0006577455388575203,
#   0.0004699572234151629,
#   0.0003964966718886888],
#  ['Site4_Loc1_BF375_1',
#   'Site4_Loc1_BF375_2',
#   'Site4_Loc1_DF002_1',
#   'Site1_Loc4_AL116_1',
#   'Site1_Loc4_AL116_2',
#   'Site1_Loc4_DF200_2',
#   'Site2_Loc1_AL116_1',
#   'Site2_Loc1_AL116_2',
#   'Site2_Loc1_AL116_3',
#   'Site2_Loc1_DF002_1',
#   'Site2_Loc1_DF002_2',
#   'Site2_Loc1_DF002_3',
#   'Site2_Loc6_AL116_1',
#   'Site2_Loc6_AL116_2',
#   'Site2_Loc6_AL116_3',
#   'Site2_Loc6_DF002_1',
#   'Site2_Loc6_DF002_2',
#   'Site2_Loc6_DF002_3',
#   'Site3_Loc1_AL116_1',
#   'Site3_Loc1_AL116_2',
#   'Site3_Loc1_AL116_3',
#   'Site3_Loc1_DF002_1',
#   'Site3_Loc1_DF002_2',
#   'Site3_Loc1_DF002_3',
#   'Site3_Loc4_AL116_1',
#   'Site3_Loc4_AL116_2',
#   'Site3_Loc4_AL116_3',
#   'Site3_Loc4_DF002_1',
#   'Site3_Loc4_DF002_2',
#   'Site3_Loc4_DF002_3',
#   'Site1_Loc1_AL116_1',
#   'Site1_Loc1_AL116_2',
#   'Site1_Loc1_AL116_3',
#   'Site1_Loc1_DF002_1',
#   'Site1_Loc1_DF002_2',
#   'Site1_Loc1_DF002_3'])

# %% [markdown]
# **SUMMARY**

# %%
cols = 1
rows = len(code_list)

matrix = [['' for _ in range(cols)] for _ in range(rows)]

for i in range(rows):
    for j in range(cols):
        matrix[i][j] = f"{i}, {code_list[i]}, {mean_ksat[i]} m/s."

# %%
matrix
# Out:
# [['0, Site4_Loc1_BF375_1, 0.00021082596475959354 m/s.'],
#  ['1, Site4_Loc1_BF375_2, 7.94187408159181e-05 m/s.'],
#  ['2, Site4_Loc1_DF002_1, 4.156487682289258e-06 m/s.'],
#  ['3, Site1_Loc4_AL116_1, 0.0005253302762321573 m/s.'],
#  ['4, Site1_Loc4_AL116_2, 0.00016269057837355112 m/s.'],
#  ['5, Site1_Loc4_DF200_2, 0.0006492857016790994 m/s.'],
#  ['6, Site2_Loc1_AL116_1, 0.00015881763238813858 m/s.'],
#  ['7, Site2_Loc1_AL116_2, 8.071894359076808e-05 m/s.'],
#  ['8, Site2_Loc1_AL116_3, 6.79133754945591e-05 m/s.'],
#  ['9, Site2_Loc1_DF002_1, 0.0002207040356640821 m/s.'],
#  ['10, Site2_Loc1_DF002_2, 0.00010997948908742784 m/s.'],
#  ['11, Site2_Loc1_DF002_3, 5.863108117639902e-05 m/s.'],
#  ['12, Site2_Loc6_AL116_1, 0.0007543736836055774 m/s.'],
#  ['13, Site2_Loc6_AL116_2, 0.0003777380755548871 m/s.'],
#  ['14, Site2_Loc6_AL116_3, 0.0003662255991882395 m/s.'],
#  ['15, Site2_Loc6_DF002_1, 0.0002668476249818098 m/s.'],
#  ['16, Site2_Loc6_DF002_2, 0.0004040185992833251 m/s.'],
#  ['17, Site2_Loc6_DF002_3, 0.0002712300028347941 m/s.'],
#  ['18, Site3_Loc1_AL116_1, 0.0003098563706534051 m/s.'],
#  ['19, Site3_Loc1_AL116_2, 0.0002209536046338748 m/s.'],
#  ['20, Site3_Loc1_AL116_3, 0.0002209536046338748 m/s.'],
#  ['21, Site3_Loc1_DF002_1, 0.000160980180932465 m/s.'],
#  ['22, Site3_Loc1_DF002_2, 7.419959053741125e-05 m/s.'],
#  ['23, Site3_Loc1_DF002_3, 6.197495156988425e-05 m/s.'],
#  ['24, Site3_Loc4_AL116_1, 5.639378223253935e-05 m/s.'],
#  ['25, Site3_Loc4_AL116_2, 5.5671352708123385e-05 m/s.'],
#  ['26, Site3_Loc4_AL116_3, 4.853354883218015e-05 m/s.'],
#  ['27, Site3_Loc4_DF002_1, 2.495131032280511e-05 m/s.'],
#  ['28, Site3_Loc4_DF002_2, 8.908771091981877e-07 m/s.'],
#  ['29, Site3_Loc4_DF002_3, 3.5461583759723865e-06 m/s.'],
#  ['30, Site1_Loc1_AL116_1, 0.0005877619318173751 m/s.'],
#  ['31, Site1_Loc1_AL116_2, 0.00041633366398485106 m/s.'],
#  ['32, Site1_Loc1_AL116_3, 0.0003565310889419914 m/s.'],
#  ['33, Site1_Loc1_DF002_1, 0.0006577455388575203 m/s.'],
#  ['34, Site1_Loc1_DF002_2, 0.0004699572234151629 m/s.'],
#  ['35, Site1_Loc1_DF002_3, 0.0003964966718886888 m/s.']]

# %%
S4_L1 = mean_ksat[0:2]
S2_L1 = mean_ksat[6:11]
S2_L6 = mean_ksat[12:17]
S1_L4 = mean_ksat[3:5]
S3_L1 = mean_ksat[18:23]
S3_L4 = mean_ksat[24:29]
S1_L1 = mean_ksat[30:35]

# %%
data = [S1_L1, S1_L4, S2_L1, S2_L6, S3_L1, S3_L4, S4_L1]
loc = ['S1_L1','S1_L4', 'S2_L1', 'S2_L6', 'S3_L1', 'S3_L4', 'S4_L1']

# %%
plt.figure(figsize=(10, 6))
plt.boxplot(data, labels=loc)
plt.ylabel('Hydraulic Conductivity (m/s)')
plt.yscale("log")
plt.title('Comparison of Hydraulic Conductivity by Location')
plt.savefig("comparison", dpi = 300)
plt.show()

# %%
cl = S4_L1 + S2_L1 + S3_L1 + S1_L1
nc = S2_L6 + S1_L4 + S3_L4
data = [cl, nc]
labels = ["cleared", "non cleared"]

# %%
plt.figure(figsize=(10, 6))
plt.boxplot(data, labels = labels)
plt.ylabel('Hydraulic Conductivity (m/s)')
plt.yscale("log")
plt.title('Comparison of Hydraulic Conductivity by Land Management Practice')
plt.savefig("comparison", dpi = 300)
plt.show()
